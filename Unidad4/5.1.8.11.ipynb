# %%
# Demonstrando min() - Ejemplo 1
print(min("aAbByYzZ"))
#la cadena no debe estar vacia
#definir una funcion
#se agrega un argumento
# Demonstrando min() - Examplos 2 y 3
t = 'Los Caballeros Que Dicen "¡Ni!"'
print('[' + min(t) + ']')

t = [0, 1, 2]
print(min(t))
# Out:
# A
# [ ]
# 0
